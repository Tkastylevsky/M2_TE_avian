# %%
import pandas as pa
import itertools
import csv
names_col = ['SW_score',"perc_div","perc_del","perc_ins", "query_seq", "pos_query_begin", "pos_query_end", "pos_query_left","strand", "matching_repeat", "repeat_class_family", "pos_in_repeat_begin", "pos_in_repeat_end", "pos_in_repeat_left", "ID","star"]

# %%
data = pa.read_csv("/home/tkastylevsky/FASTA_files/Gallus_gallus.GRCg6a.dna.chromosome.16.fa.out",header = None, skiprows = 2, sep = '\s+', names = names_col)
data['strand'] = data['strand'].replace('C','-')
ref = pa.read_csv("/home/tkastylevsky/FASTA_files/chkchr16_refgalGal6", sep = '\s+')
ref = ref.drop(["#bin","repFamily"], axis = 1)
ref.insert(15,"star", 'NaN')
ref.columns = names_col
ref.insert(16,"Type", 'Ref')
data.insert(16, "Type", 'Data')

# %%
analysis_df = data.append(ref)
analysis_df.insert(17,"ID_2",list(range(0, len(analysis_df))))

# %%
analysis_df['intersect'] = analysis_df.apply(lambda row: len(analysis_df[ ( ( (row.pos_query_begin <= analysis_df.pos_query_begin) & (analysis_df.pos_query_begin <= row.pos_query_end) ) \
                                            | ( (analysis_df.pos_query_begin <= row.pos_query_begin) & (row.pos_query_begin <= analysis_df.pos_query_end) ) )
                           & (row.ID_2 != analysis_df.ID_2) & (row.Type != analysis_df.Type) & (row.repeat_class_family == analysis_df.repeat_class_family) ]),axis=1)

# %%
analysis_df[0:30]
analysis_df[analysis_df['intersect'] !=0 ]
# Out:
#       SW_score  perc_div  perc_del  perc_ins query_seq  pos_query_begin  \
# 0           24      30.7       0.0       0.0        16           503450
# 1           12      15.6       3.5       0.0        16           524575
# 2           15       0.0       0.0       0.0        16           528437
# 3           13      20.1       2.2       4.5        16           529013
# 4           15       7.9       3.7       0.0        16           529232
# ...        ...       ...       ...       ...       ...              ...
# 2324        15      47.0       0.0       0.0     chr16          2832425
# 2325        16     161.0       0.0       0.0     chr16          2832505
# 2326        13     184.0      70.0       0.0     chr16          2834738
# 2327        14     153.0      43.0      43.0     chr16          2840336
# 2329        16     132.0       0.0       0.0     chr16          2841517
#
#       pos_query_end pos_query_left strand matching_repeat repeat_class_family  \
# 0            503521      (2341080)      +           (CC)n       Simple_repeat
# 1            524603      (2319998)      +         (CCGG)n       Simple_repeat
# 2            528455      (2316146)      +          (CGG)n       Simple_repeat
# 3            529057      (2315544)      +      (CCTTCTC)n       Simple_repeat
# 4            529258      (2315343)      +          (GGC)n       Simple_repeat
# ...             ...            ...    ...             ...                 ...
# 2324        2832447         -12154      +          (GGA)n       Simple_repeat
# 2325        2832533         -12068      +          G-rich      Low_complexity
# 2326        2834781          -9820      +       (GCCGAA)n       Simple_repeat
# 2327        2840383          -4218      +          G-rich      Low_complexity
# 2329        2841542          -3059      +            (G)n       Simple_repeat
#
#      pos_in_repeat_begin  pos_in_repeat_end pos_in_repeat_left  ID star  Type  \
# 0                      1                 72                (0)   1  NaN  Data
# 1                      1                 30                (0)   2  NaN  Data
# 2                      1                 19                (0)   3  NaN  Data
# 3                      1                 44                (0)   4  NaN  Data
# 4                      1                 28                (0)   5  NaN  Data
# ...                  ...                ...                ...  ..  ...   ...
# 2324                   1                 22                  0   1  NaN   Ref
# 2325                   1                 28                  0   1  NaN   Ref
# 2326                   1                 46                  0   1  NaN   Ref
# 2327                   1                 47                  0   1  NaN   Ref
# 2329                   1                 25                  0   1  NaN   Ref
#
#       ID_2  intersect
# 0        0          1
# 1        1          1
# 2        2          1
# 3        3          1
# 4        4          1
# ...    ...        ...
# 2324  3983          1
# 2325  3984          1
# 2326  3985          1
# 2327  3986          1
# 2329  3988          1
#
# [1050 rows x 19 columns]

# %%
# Out:
#       SW_score  perc_div  perc_del  perc_ins  query_seq  pos_query_begin  \
# 0           24      30.7       0.0       0.0         16           503450
# 1           12      15.6       3.5       0.0         16           524575
# 2           15       0.0       0.0       0.0         16           528437
# 3           13      20.1       2.2       4.5         16           529013
# 4           15       7.9       3.7       0.0         16           529232
# ...        ...       ...       ...       ...        ...              ...
# 1654        35      30.6       0.6       4.5         16          2834861
# 1655       473      22.3       2.7       2.1         16          2835026
# 1656       711      24.3       1.1       0.7         16          2837245
# 1657        14      15.3       4.3       4.3         16          2840337
# 1658        16      13.2       0.0       0.0         16          2841518
#
#       pos_query_end pos_query_left strand  matching_repeat  \
# 0            503521      (2341080)      +            (CC)n
# 1            524603      (2319998)      +          (CCGG)n
# 2            528455      (2316146)      +           (CGG)n
# 3            529057      (2315544)      +       (CCTTCTC)n
# 4            529258      (2315343)      +           (GGC)n
# ...             ...            ...    ...              ...
# 1654        2835020         (9581)      +           (CCG)n
# 1655        2835303         (9298)      -  rnd-1_family-59
# 1656        2837513         (7088)      -  rnd-1_family-59
# 1657        2840383         (4218)      +           G-rich
# 1658        2841542         (3059)      +             (G)n
#
#      repeat_class_family pos_in_repeat_begin  pos_in_repeat_end  \
# 0          Simple_repeat                   1                 72
# 1          Simple_repeat                   1                 30
# 2          Simple_repeat                   1                 19
# 3          Simple_repeat                   1                 44
# 4          Simple_repeat                   1                 28
# ...                  ...                 ...                ...
# 1654       Simple_repeat                   1                154
# 1655           Satellite               (127)                279
# 1656           Satellite                 (0)                270
# 1657      Low_complexity                   1                 47
# 1658       Simple_repeat                   1                 25
#
#      pos_in_repeat_left    ID star  Type
# 0                   (0)     1  NaN  Data
# 1                   (0)     2  NaN  Data
# 2                   (0)     3  NaN  Data
# 3                   (0)     4  NaN  Data
# 4                   (0)     5  NaN  Data
# ...                 ...   ...  ...   ...
# 1654                (0)  1508  NaN  Data
# 1655                  1  1509  NaN  Data
# 1656                  1  1510  NaN  Data
# 1657                (0)  1511  NaN  Data
# 1658                (0)  1512  NaN  Data
#
# [1659 rows x 17 columns]
