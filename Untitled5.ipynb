# %%
import pandas as pa

# %%
path_data = '/home/tkastylevsky/results/bedtools_analysis/whole_libwholeVSref_whole/'
path_besthits = path_data + ' best_hits_ whole_libwhole _on_ ref_whole'

# %%
best_hits_lib_on_ref = pa.read_csv(path_besthits)
best_hits_lib_on_ref
# Out:
#                                chr      A_source  A_start  A_end  A_perc_div  \
# 0                             chr1  RepeatMasker    11446  11462         0.0
# 1                             chr1  RepeatMasker    14221  14280        19.5
# 2                             chr1  RepeatMasker    19982  20019        22.4
# 3                             chr1  RepeatMasker    20120  20535        33.3
# 4                             chr1  RepeatMasker    21028  21265        20.3
# ...                            ...           ...      ...    ...         ...
# 632561  chrZ_NW_020109829v1_random  RepeatMasker     5505   7639        16.5
# 632562  chrZ_NW_020109829v1_random  RepeatMasker     9858  10077         2.3
# 632563  chrZ_NW_020109829v1_random  RepeatMasker    10151  10325         8.6
# 632564  chrZ_NW_020109829v1_random  RepeatMasker    10320  12533         1.7
# 632565  chrZ_NW_020109829v1_random  RepeatMasker    12547  15587         0.3
#
#           A_ID      B_source  B_start  B_end  B_perc_div    B_ID  \
# 0            2  RepeatMasker    11446  11462         0.0       8
# 1            3  RepeatMasker    14221  14280        19.5       9
# 2           10  RepeatMasker    19972  20535        35.1      11
# 3           11  RepeatMasker    19972  20535        35.1      11
# 4           13  RepeatMasker    21000  21267        13.8      12
# ...        ...           ...      ...    ...         ...     ...
# 632561  763213  RepeatMasker     5512   7615         6.3  698943
# 632562  763214  RepeatMasker     9853  10077         3.1  698944
# 632563  763215  RepeatMasker    10151  10325        13.7  698945
# 632564  763216  RepeatMasker    10320  12533         2.0  698946
# 632565  763217  RepeatMasker    12547  15587         0.8  698947
#
#         A_repeat_class A_repeat_family B_repeat_class B_repeat_family  \
# 0        Simple_repeat             NaN  Simple_repeat             NaN
# 1        Simple_repeat             NaN  Simple_repeat             NaN
# 2       Low_complexity             NaN           LINE             CR1
# 3                 LINE             CR1           LINE             CR1
# 4                 LINE             CR1           LINE             CR1
# ...                ...             ...            ...             ...
# 632561            LINE             CR1           LINE             CR1
# 632562             LTR         Unknown            LTR            ERVL
# 632563            LINE             CR1           LINE             CR1
# 632564             LTR            ERVL            LTR            ERVL
# 632565             LTR            ERVK            LTR            ERVK
#
#         A_intersect  B_intersect
# 0          1.000000     1.000000
# 1          1.000000     1.000000
# 2          1.000000     0.065719
# 3          1.000000     0.737123
# 4          1.000000     0.887640
# ...             ...          ...
# 632561     0.985473     1.000000
# 632562     1.000000     0.977679
# 632563     1.000000     1.000000
# 632564     1.000000     1.000000
# 632565     1.000000     1.000000
#
# [632566 rows x 17 columns]

# %%
best_hits_lib_on_ref['hit'] = 0
best_hits_lib_on_ref.loc[best_hits_lib_on_ref.A_repeat_class == best_hits_lib_on_ref.B_repeat_class,'hit']
# Out:
# /home/tkastylevsky/programs/Anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# Out:
#   File "<ipython-input-21-ef0d103eb281>", line 2
#     jt -t chesterish
#                    ^
# SyntaxError: invalid syntax
